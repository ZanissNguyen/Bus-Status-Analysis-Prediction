# %% [markdown]
# # Ref
# @article{article,
# author = {Cuong, Pham and Nguyen, Ngoc Tuyen and Tran, Tra and Nguyen, Nhu},
# year = {2024},
# month = {05},
# pages = {012031},
# title = {Prediction of surface urban heat island in Ho Chi Minh City, Viet Nam using remote sensing and logistic regression model},
# volume = {1349},
# journal = {IOP Conference Series: Earth and Environmental Science},
# doi = {10.1088/1755-1315/1349/1/012031}
# }
