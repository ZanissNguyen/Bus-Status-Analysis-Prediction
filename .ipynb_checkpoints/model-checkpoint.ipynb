# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import json
from datetime import datetime
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Loading Data

# %%
files = ["preprocessed_data_1.json", "preprocessed_data_2.json", "preprocessed_data_3.json"]
data = []
for file in files:
    with open(file, "r", encoding="utf-8") as f:
        data += [pd.DataFrame(json.load(f))]

df = pd.concat(data, ignore_index=True)
print(df.head())
print(len(df))
# Out:
#         start station         end station           start time  \
# 0       Ngã tư An Lạc     Bến xe An Sương  21-03-2025 11:09:47
# 1       Cư xá Bà Điểm  Qua ngã tư Bà Điểm  25-04-2025 06:05:37
# 2  Qua ngã tư Bà Điểm       Cư xá Bà Điểm  25-04-2025 17:15:53
# 3       Cư xá Bà Điểm       Ngã tư An Lạc  25-04-2025 17:23:23
# 4       Cư xá Bà Điểm       Ngã tư An Lạc  27-04-2025 06:54:27
#
#               end time  week day  distance (m)  duration (s)  speed (kmh)
# 0  21-03-2025 14:04:00         4  12783.877980         10453     4.402751
# 1  25-04-2025 17:15:53         4   1357.213112         40216     0.121493
# 2  25-04-2025 17:23:23         4   1357.039923           450    10.856319
# 3  25-04-2025 19:23:23         4  13006.745440          7200     6.503373
# 4  27-04-2025 10:28:44         6  13016.317826         12857     3.644609
# 3413

# %% [markdown]
# # Preprocessing

# %%
df["start time"] = pd.to_datetime(df["start time"], format="%d-%m-%Y %H:%M:%S")
df["end time"] = pd.to_datetime(df["end time"], format="%d-%m-%Y %H:%M:%S")

df = df[df["start time"].dt.day == df["end time"].dt.day].reset_index(drop=True)

df["hour"] = df["start time"].dt.hour
df["weekend"] = (df["week day"]>=5).astype(int)
df = df.drop(columns=["end time"])
df = df.drop(columns=["start time"])
df = df.drop(columns=["speed (kmh)"])

df["route"] = df["start station"] + "_" + df["end station"]
route_mean = (
    df.groupby("route")["duration (s)"]
      .mean()
      .rename("route_avg_duration")
)
df = df.merge(route_mean, on="route")
# df = df.drop(columns=["start station"])
# df = df.drop(columns=["end station"])

print(df.head(30))
print(len(df))
# Out:
#                   start station                   end station  week day  \
# 0                 Ngã tư An Lạc               Bến xe An Sương         4
# 1                 Cư xá Bà Điểm            Qua ngã tư Bà Điểm         4
# 2            Qua ngã tư Bà Điểm                 Cư xá Bà Điểm         4
# 3                 Cư xá Bà Điểm                 Ngã tư An Lạc         4
# 4                 Cư xá Bà Điểm                 Ngã tư An Lạc         6
# 5                 Ngã tư An Lạc                 Cư xá Bà Điểm         6
# 6                 Cư xá Bà Điểm               Bến xe An Sương         6
# 7               Bến xe An Sương                         SinCo         6
# 8                         SinCo                 Ngã tư An Lạc         6
# 9                 Ngã tư An Lạc                 Cư xá Bà Điểm         1
# 10                Cư xá Bà Điểm                 Ngã tư An Lạc         1
# 11                       Chợ Củ                      Hàm Nghi         3
# 12                     Hàm Nghi           Khách sạn New world         3
# 13          Khách sạn New world           Bện viện Nhi Đồng 1         3
# 14          Bện viện Nhi Đồng 1               Đại học Sài Gòn         3
# 15             Trường Cao Thắng                      Hàm Nghi         4
# 16                     Hàm Nghi                    Trống Đồng         4
# 17                   Trống Đồng         Vòng xoay Lê Đại Hành         4
# 18        Vòng xoay Lê Đại Hành                   Chợ Bầu Sen         4
# 19                  Chợ Bầu Sen               Đại học Sài Gòn         4
# 20              Đại học Sài Gòn                      Hàm Nghi         4
# 21                     Hàm Nghi   Hội Chữ thập đỏ thành phố         4
# 22  Hội Chữ thập đỏ thành phố               Đại học Sài Gòn         4
# 23              Đại học Sài Gòn                    Nguyễn Kim         4
# 24                   Nguyễn Kim                   Chợ Bầu Sen         4
# 25                  Chợ Bầu Sen                      Hàm Nghi         4
# 26                     Hàm Nghi                    Trống Đồng         4
# 27                Tôn Thất Tùng  Cổng ra - Bến xe Miền Đông 3         4
# 28                      Sở Y Tế                 Tôn Thất Tùng         0
# 29                Tôn Thất Tùng                       Sở Y Tế         0
#
#     distance (m)  duration (s)  hour  weekend  \
# 0   12783.877980         10453    11        0
# 1    1357.213112         40216     6        0
# 2    1357.039923           450    17        0
# 3   13006.745440          7200    17        0
# 4   13016.317826         12857     6        1
# 5   13016.089867         18996    10        1
# 6     228.740923           260    15        1
# 7   12477.052378          6208    15        1
# 8     554.625824           100    17        1
# 9   13008.571059          1872     7        0
# 10  13017.390809         12536     7        0
# 11    258.536652           114     7        0
# 12    423.999399           142     7        0
# 13   2854.589768         20740     7        0
# 14   1582.180975          4630    12        0
# 15    223.277812            90     6        0
# 16    988.708754           250     6        0
# 17   4308.407867          4123     6        0
# 18   3151.205450          1895     7        0
# 19    450.320865           121     8        0
# 20   2236.621939          3930     8        0
# 21   1782.479925           662     9        0
# 22    814.016298          4209     9        0
# 23   1720.547703           883    10        0
# 24   2177.876078          9426    10        0
# 25   2675.098908          5187    13        0
# 26    975.179336           250    15        0
# 27   5360.856116         27002    15        0
# 28    630.915663          2283    14        0
# 29    633.681732         20579    14        0
#
#                                           route  route_avg_duration
# 0                 Ngã tư An Lạc_Bến xe An Sương         6571.285714
# 1              Cư xá Bà Điểm_Qua ngã tư Bà Điểm        40216.000000
# 2              Qua ngã tư Bà Điểm_Cư xá Bà Điểm          450.000000
# 3                   Cư xá Bà Điểm_Ngã tư An Lạc        11703.000000
# 4                   Cư xá Bà Điểm_Ngã tư An Lạc        11703.000000
# 5                   Ngã tư An Lạc_Cư xá Bà Điểm         6934.833333
# 6                 Cư xá Bà Điểm_Bến xe An Sương          730.368421
# 7                         Bến xe An Sương_SinCo        17868.333333
# 8                           SinCo_Ngã tư An Lạc         5835.461538
# 9                   Ngã tư An Lạc_Cư xá Bà Điểm         6934.833333
# 10                  Cư xá Bà Điểm_Ngã tư An Lạc        11703.000000
# 11                              Chợ Củ_Hàm Nghi         1941.000000
# 12                 Hàm Nghi_Khách sạn New world          136.000000
# 13      Khách sạn New world_Bện viện Nhi Đồng 1        20740.000000
# 14          Bện viện Nhi Đồng 1_Đại học Sài Gòn         4227.500000
# 15                    Trường Cao Thắng_Hàm Nghi          110.652174
# 16                          Hàm Nghi_Trống Đồng          280.750000
# 17             Trống Đồng_Vòng xoay Lê Đại Hành         4123.000000
# 18            Vòng xoay Lê Đại Hành_Chợ Bầu Sen         1895.000000
# 19                  Chợ Bầu Sen_Đại học Sài Gòn         1248.000000
# 20                     Đại học Sài Gòn_Hàm Nghi        13944.666667
# 21         Hàm Nghi_Hội Chữ thập đỏ thành phố          564.000000
# 22  Hội Chữ thập đỏ thành phố_Đại học Sài Gòn         4209.000000
# 23                   Đại học Sài Gòn_Nguyễn Kim          642.666667
# 24                       Nguyễn Kim_Chợ Bầu Sen         9426.000000
# 25                         Chợ Bầu Sen_Hàm Nghi         5187.000000
# 26                          Hàm Nghi_Trống Đồng          280.750000
# 27   Tôn Thất Tùng_Cổng ra - Bến xe Miền Đông 3        27002.000000
# 28                        Sở Y Tế_Tôn Thất Tùng         2283.000000
# 29                        Tôn Thất Tùng_Sở Y Tế        20579.000000
# 3413

# %%
# # duration
# plt.figure(figsize=(8,5))
# sns.histplot(df["duration (s)"], bins=50)
# plt.title("Duration Distribution")
# plt.show()

# # duration vs distance
# plt.figure(figsize=(7,5))
# sns.scatterplot(
#     x="distance (m)",
#     y="duration (s)",
#     data=df
# )
# plt.show()

# sns.boxplot(x="hour", y="duration (s)", data=df)
# plt.xticks(rotation=45)
# plt.show()

# sns.boxplot(x="weekend", y="duration (s)", data=df)
# plt.show()

# plt.figure(figsize=(6,5))
# sns.heatmap(
#     df.corr(numeric_only=True),
#     annot=True,
#     cmap="coolwarm"
# )
# plt.show()

# sns.lineplot(
#     x="hour",
#     y="speed (kmh)",
#     data=df,
#     estimator="mean"
# )
# plt.show()

# %%
X = df.drop(columns=["duration (s)"])
Y = df["duration (s)"]

# categorical_cols = ["route"]
categorical_cols = ["start station", "end station"]
numeric_cols = ["distance (m)", "week day", "hour", "weekend", "route_avg_duration"]
# numeric_cols = ["distance (m)", "week day", "hour", "weekend"]

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
        ("num", "passthrough", numeric_cols)
    ]
)

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42)

# %%
linear_model = Pipeline([
    ("preprocess", preprocessor),
    ("model", LinearRegression())
])

linear_model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['start station',
#                                                    'end station']),
#                                                  ('num', 'passthrough',
#                                                   ['distance (m)', 'week day',
#                                                    'hour', 'weekend'])])),
#                 ('model', LinearRegression())])

# %%
pred_lr = linear_model.predict(X_test)

print("MAE:", mean_absolute_error(Y_test, pred_lr))
print("RMSE:", np.sqrt(mean_squared_error(Y_test, pred_lr)))
print("R2:", r2_score(Y_test, pred_lr))
# Out:
# MAE: 4596.048603908233
# RMSE: 7083.513337585527
# R2: 0.15236990604320144
